# %%
#  I'm going to make this one big function that is called to update the sqlite database from 
#  a route in app.py

#  import statements
import pandas as pd
import requests
import json
from sqlalchemy import create_engine
from config import BEA_GDP_url
from config import BEA_pop_url
# REPLACE 'WILDCARD' with 51, 52, 53

# JSON for per year change over year/state, empty at start, need to run updateDB to get values
yearly_change_dict_states = {}
yearly_change_dict_regions = {}
DB_dict = {}
DB_r_dict = {}

# BEA_GDP: 
# note that value in millions of 2012 dollars
# index for alabama starts at 21
skipCountry = 21
# dict structure {'BEAAPI': {'Results': 'Data': [21:]}}
# within that we want {'GeoName', 'TimePeriod', 'DataValue'}

# BEA_pop with WILDCARD = 51, same dict structure, same values wanted (51 is for personal disposable income)
# stored as millions of dollars (not necessarily 2012 dollars?)
# after checking, all 51, 52, 53 have same required structure, noting here that 52 is population (persons) and 53 is
# personal disposable income per capita (53 in dollars, not millions)

raw_GDP_dict = requests.get(BEA_GDP_url).json()
raw_pop_dict_list = []
for i in ['51', '52', '53']:
    BEA_pop_temp_url = BEA_pop_url.replace('WILDCARD', i)
    raw_pop_dict_list.append(requests.get(BEA_pop_temp_url).json())
    # now index 0 refers to 51, 1 to 52, 2 to 53
# Going to store as {'$YEAR$' : '$STATE$' : {keys-values}}

DB_dict = {}

# make a list of the regions to set them in another table
regions = [
    'NewEngland', 'Mideast', 'GreatLakes', 'Plains', 'Southeast', 'Southwest', 'RockyMountain', 'Farwest'
]
# first set the $YEAR$ keys
for y in range(1997, 2018):
    DB_dict[y] = {}
# stored $YEAR$ as integer key for dictionary
# next set state keys and other values
for data_d in raw_GDP_dict['BEAAPI']['Results']['Data'][skipCountry:]:
# fixing up data format
    dataVal = data_d['DataValue'].split(',')
    dataVal = ''.join(dataVal)
    geoName = data_d['GeoName']
    geoName = ''.join([c for c in geoName if c.isalpha()])
    DB_dict[int(data_d['TimePeriod'])][geoName] = {}
    DB_dict[int(data_d['TimePeriod'])][geoName]['GDP (millions of dollars)'] = float(dataVal)
    # now DB_dict[$YEAR$][$STATE$]['GDP'] = $GDP$ in millions
    # also now the year/state is typed as a dictionary, so the first line in the for loop
    #   is no longer required (in the next 3 dictionaries)
categories = ['Personal Disposable Income (millions of dollars)', 'Population (persons)', 'Personal Disposable Income per capita (dollars)']
category = -1
for pop_dict in raw_pop_dict_list:
    category += 1
    for data_d in pop_dict['BEAAPI']['Results']['Data'][skipCountry:]:
    # fixing up the data format
        dataVal = data_d['DataValue'].split(',')
        dataVal = ''.join(dataVal)
        geoName = data_d['GeoName']
        geoName = ''.join([c for c in geoName if c.isalpha()])
        DB_dict[int(data_d['TimePeriod'])][geoName][categories[category]] = float(dataVal)
# now DB_dict[$YEAR$][$STATE$] has GDP, $categories$ keys and stored values as floats

# DB_dict now has the desired structure

# Split DB_dict into state_dict and region_dict
state_dict = {}
region_dict = {}
for year in list(DB_dict.keys()):
    state_dict[year] = {}
    region_dict[year] = {}
    for key in list(DB_dict[year].keys()):
        if key in regions:
            region_dict[year][key] = DB_dict[year][key]
        else:
            state_dict[year][key] = DB_dict[year][key]


# update yearly_change_dict using DB_dict
# updating the structure of y_c_d to be similar to DB_dict
yearly_change_dict = {}
years = list(DB_dict.keys())
for i in range(len(years)):
    yearly_change_dict[years[i]] = {}
    states = list(DB_dict[years[i]].keys())
    for state in states:
        if (i > 0):
            yearly_change_dict[years[i]][state] = {
                'GDP Change': DB_dict[years[i]][state]['GDP (millions of dollars)'] - DB_dict[years[i - 1]][state]['GDP (millions of dollars)'],
                'Personal Dist Income Change': DB_dict[years[i]][state][categories[0]] - DB_dict[years[i - 1]][state][categories[0]],
                'Population Change': DB_dict[years[i]][state][categories[1]] - DB_dict[years[i - 1]][state][categories[1]],
                'Personal Dist Income Per Capita Change': DB_dict[years[i]][state][categories[2]] - DB_dict[years[i - 1]][state][categories[2]]
            }
            # if this is the first year, change should be = entry
        else:
            yearly_change_dict[years[i]][state] = {
                'GDP Change': 0,
                'Personal Dist Income Change': 0,
                'Population Change': 0,
                'Personal Dist Income Per Capita Change': 0
            }

# split yearly_change_dict into _regions, _states
for year in years:
    yearly_change_dict_regions[year] = {}
    yearly_change_dict_states[year] = {}
    for key in list(yearly_change_dict[year].keys()):
        if key in regions:
            yearly_change_dict_regions[year][key] = yearly_change_dict[year][key]
        else:
            yearly_change_dict_states[year][key] = yearly_change_dict[year][key]

# put the changes into the dictionary for DB_DF, DB_regions_DF
# final_state_dict,final_region_dict
final_state_dict = {}
final_region_dict = {}
for year in years:
    final_state_dict[year] = {}
    final_region_dict[year] = {}
    for key in list(state_dict[year].keys()):
        final_state_dict[year][key] = state_dict[year][key]
    for key in list(region_dict[year].keys()):
        final_region_dict[year][key] = region_dict[year][key]
    for key in list(yearly_change_dict_states[year].keys()):
        final_state_dict[year][key].update(yearly_change_dict_states[year][key])
    for key in list(yearly_change_dict_regions[year].keys()):
        final_region_dict[year][key].update(yearly_change_dict_regions[year][key])

# create a DataFrame object using DB_dict
# multi-indexed

DB_DF = pd.DataFrame.from_dict({(i,j): final_state_dict[i][j] for i in final_state_dict.keys() for j in final_state_dict[i].keys()}, orient = 'index')
DB_regions_DF = pd.DataFrame.from_dict({(i,j): final_region_dict[i][j] for i in final_region_dict.keys() for j in final_region_dict[i].keys()}, orient = 'index')


# next create/update the sqlite database
engine = create_engine('sqlite:///p3.db', echo = False)
conn = engine.connect()

DB_DF.to_sql(name = 'info_by_year_state', con = conn, if_exists = 'replace')
DB_regions_DF.to_sql(name = 'info_by_year_region', con = conn, if_exists = 'replace')

#engine = create_engine('sqlite:///p3.db', echo=False)
#conn = engine.connect()

#engine.execute("SELECT * FROM info_by_year_state").fetchall()

db_df = pd.read_sql('info_by_year_state', con = conn)
db_r_df = pd.read_sql('info_by_year_region', con = conn)

db_df.rename(index=str, columns={"level_0": "Year"},inplace=True)
db_r_df.rename(index=str, columns={"level_0": "Year"},inplace=True)

db_df.rename(index=str, columns={"level_1": "State"},inplace=True)
db_r_df.rename(index=str, columns={"level_1": "Region"},inplace=True)

db_df_ys = db_df.set_index(['Year', 'State'], inplace=False)
db_df_yr = db_r_df.set_index(['Year', 'Region'], inplace=False)

db_df_ys_dict = db_df_ys.to_dict('index')
db_df_yr_dict = db_df_yr.to_dict('index')

for (key1,key2) in db_df_ys_dict.keys():
    DB_dict[key1] = {}
for (key1,key2) in db_df_yr_dict.keys():
    DB_r_dict[key1] = {}

for (key1,key2) in db_df_ys_dict.keys():
    DB_dict[key1][key2] = {}
for (key1,key2) in db_df_yr_dict.keys():
    DB_r_dict[key1][key2] = {}

for (key1,key2) in db_df_ys_dict.keys():
    DB_dict[key1][key2] = db_df_ys_dict[(key1,key2)]
for (key1,key2) in db_df_yr_dict.keys():
    DB_r_dict[key1][key2] = db_df_yr_dict[(key1,key2)]
conn.close()

# %%
yearly_change_dict_regions
# Out:
# {1997: {'NewEngland': {'GDP Change': 0,
#    'Personal Dist Income Change': 0,
#    'Population Change': 0,
#    'Personal Dist Income Per Capita Change': 0},
#   'Mideast': {'GDP Change': 0,
#    'Personal Dist Income Change': 0,
#    'Population Change': 0,
#    'Personal Dist Income Per Capita Change': 0},
#   'GreatLakes': {'GDP Change': 0,
#    'Personal Dist Income Change': 0,
#    'Population Change': 0,
#    'Personal Dist Income Per Capita Change': 0},
#   'Plains': {'GDP Change': 0,
#    'Personal Dist Income Change': 0,
#    'Population Change': 0,
#    'Personal Dist Income Per Capita Change': 0},
#   'Southeast': {'GDP Change': 0,
#    'Personal Dist Income Change': 0,
#    'Population Change': 0,
#    'Personal Dist Income Per Capita Change': 0},
#   'Southwest': {'GDP Change': 0,
#    'Personal Dist Income Change': 0,
#    'Population Change': 0,
#    'Personal Dist Income Per Capita Change': 0},
#   'RockyMountain': {'GDP Change': 0,
#    'Personal Dist Income Change': 0,
#    'Population Change': 0,
#    'Personal Dist Income Per Capita Change': 0}},
#  1998: {'NewEngland': {'GDP Change': 24343.0,
#    'Personal Dist Income Change': 21291.800000000047,
#    'Population Change': 91631.0,
#    'Personal Dist Income Per Capita Change': 1379.0},
#   'Mideast': {'GDP Change': 56664.0,
#    'Personal Dist Income Change': 63510.80000000005,
#    'Population Change': 242306.0,
#    'Personal Dist Income Per Capita Change': 1252.0},
#   'GreatLakes': {'GDP Change': 65070.40000000014,
#    'Personal Dist Income Change': 57532.70000000007,
#    'Population Change': 234274.0,
#    'Personal Dist Income Per Capita Change': 1168.0},
#   'Plains': {'GDP Change': 23853.699999999953,
#    'Personal Dist Income Change': 26348.79999999999,
#    'Population Change': 136702.0,
#    'Personal Dist Income Per Capita Change': 1230.0},
#   'Southeast': {'GDP Change': 118681.8999999999,
#    'Personal Dist Income Change': 96592.90000000014,
#    'Population Change': 971281.0,
#    'Personal Dist Income Per Capita Change': 1130.0},
#   'Southwest': {'GDP Change': 72393.69999999995,
#    'Personal Dist Income Change': 48206.5,
#    'Population Change': 614488.0,
#    'Personal Dist Income Per Capita Change': 1175.0},
#   'RockyMountain': {'GDP Change': 25876.099999999977,
#    'Personal Dist Income Change': 15655.5,
#    'Population Change': 172234.0,
#    'Personal Dist Income Per Capita Change': 1347.0}},
#  1999: {'NewEngland': {'GDP Change': 29112.099999999977,
#    'Personal Dist Income Change': 21930.699999999953,
#    'Population Change': 103825.0,
#    'Personal Dist Income Per Capita Change': 1381.0},
#   'Mideast': {'GDP Change': 98323.5,
#    'Personal Dist Income Change': 59968.89999999991,
#    'Population Change': 283809.0,
#    'Personal Dist Income Per Capita Change': 1138.0},
#   'GreatLakes': {'GDP Change': 73211.69999999995,
#    'Personal Dist Income Change': 45300.89999999991,
#    'Population Change': 241348.0,
#    'Personal Dist Income Per Capita Change': 880.0},
#   'Plains': {'GDP Change': 21840.20000000007,
#    'Personal Dist Income Change': 18430.0,
#    'Population Change': 142783.0,
#    'Personal Dist Income Per Capita Change': 791.0},
#   'Southeast': {'GDP Change': 122185.3999999999,
#    'Personal Dist Income Change': 71281.5,
#    'Population Change': 942800.0,
#    'Personal Dist Income Per Capita Change': 738.0},
#   'Southwest': {'GDP Change': 58528.80000000005,
#    'Personal Dist Income Change': 32296.099999999977,
#    'Population Change': 587721.0,
#    'Personal Dist Income Per Capita Change': 633.0},
#   'RockyMountain': {'GDP Change': 24040.900000000023,
#    'Personal Dist Income Change': 12808.399999999994,
#    'Population Change': 176314.0,
#    'Personal Dist Income Per Capita Change': 972.0}},
#  2000: {'NewEngland': {'GDP Change': 51186.10000000009,
#    'Personal Dist Income Change': 34448.40000000002,
#    'Population Change': 112068.0,
#    'Personal Dist Income Per Capita Change': 2240.0},
#   'Mideast': {'GDP Change': 90991.29999999981,
#    'Personal Dist Income Change': 100565.19999999995,
#    'Population Change': 280193.0,
#    'Personal Dist Income Per Capita Change': 2001.0},
#   'GreatLakes': {'GDP Change': 59085.30000000005,
#    'Personal Dist Income Change': 75446.6000000001,
#    'Population Change': 246794.0,
#    'Personal Dist Income Per Capita Change': 1534.0},
#   'Plains': {'GDP Change': 36941.19999999995,
#    'Personal Dist Income Change': 31192.400000000023,
#    'Population Change': 144576.0,
#    'Personal Dist Income Per Capita Change': 1439.0},
#   'Southeast': {'GDP Change': 68545.6000000001,
#    'Personal Dist Income Change': 109530.30000000005,
#    'Population Change': 927851.0,
#    'Personal Dist Income Per Capita Change': 1274.0},
#   'Southwest': {'GDP Change': 48057.19999999995,
#    'Personal Dist Income Change': 57273.59999999998,
#    'Population Change': 553382.0,
#    'Personal Dist Income Per Capita Change': 1430.0},
#   'RockyMountain': {'GDP Change': 26671.29999999999,
#    'Personal Dist Income Change': 19141.5,
#    'Population Change': 174465.0,
#    'Personal Dist Income Per Capita Change': 1623.0}},
#  2001: {'NewEngland': {'GDP Change': 9731.0,
#    'Personal Dist Income Change': 26756.70000000001,
#    'Population Change': 91322.0,
#    'Personal Dist Income Per Capita Change': 1706.0},
#   'Mideast': {'GDP Change': 51059.60000000009,
#    'Personal Dist Income Change': 50215.40000000014,
#    'Population Change': 233346.0,
#    'Personal Dist Income Per Capita Change': 928.0},
#   'GreatLakes': {'GDP Change': -21913.90000000014,
#    'Personal Dist Income Change': 41725.39999999991,
#    'Population Change': 185545.0,
#    'Personal Dist Income Per Capita Change': 813.0},
#   'Plains': {'GDP Change': -843.5999999999767,
#    'Personal Dist Income Change': 18477.899999999965,
#    'Population Change': 99555.0,
#    'Personal Dist Income Per Capita Change': 824.0},
#   'Southeast': {'GDP Change': 39643.60000000009,
#    'Personal Dist Income Change': 79732.29999999981,
#    'Population Change': 820727.0,
#    'Personal Dist Income Per Capita Change': 855.0},
#   'Southwest': {'GDP Change': 33071.30000000005,
#    'Personal Dist Income Change': 47500.80000000005,
#    'Population Change': 511235.0,
#    'Personal Dist Income Per Capita Change': 1107.0},
#   'RockyMountain': {'GDP Change': 5281.900000000023,
#    'Personal Dist Income Change': 13182.5,
#    'Population Change': 162056.0,
#    'Personal Dist Income Per Capita Change': 966.0}},
#  2002: {'NewEngland': {'GDP Change': 7287.0,
#    'Personal Dist Income Change': 19714.70000000001,
#    'Population Change': 81398.0,
#    'Personal Dist Income Per Capita Change': 1209.0},
#   'Mideast': {'GDP Change': 16443.0,
#    'Personal Dist Income Change': 62960.5,
#    'Population Change': 221817.0,
#    'Personal Dist Income Per Capita Change': 1200.0},
#   'GreatLakes': {'GDP Change': 39824.30000000005,
#    'Personal Dist Income Change': 40138.90000000014,
#    'Population Change': 148720.0,
#    'Personal Dist Income Per Capita Change': 793.0},
#   'Plains': {'GDP Change': 19887.199999999953,
#    'Personal Dist Income Change': 20638.600000000035,
#    'Population Change': 93042.0,
#    'Personal Dist Income Per Capita Change': 935.0},
#   'Southeast': {'GDP Change': 66675.8999999999,
#    'Personal Dist Income Change': 85237.70000000019,
#    'Population Change': 833707.0,
#    'Personal Dist Income Per Capita Change': 908.0},
#   'Southwest': {'GDP Change': 31303.199999999953,
#    'Personal Dist Income Change': 33024.5,
#    'Population Change': 539080.0,
#    'Personal Dist Income Per Capita Change': 604.0},
#   'RockyMountain': {'GDP Change': 4759.799999999988,
#    'Personal Dist Income Change': 9606.700000000012,
#    'Population Change': 136295.0,
#    'Personal Dist Income Per Capita Change': 632.0}},
#  2003: {'NewEngland': {'GDP Change': 17636.0,
#    'Personal Dist Income Change': 16267.399999999965,
#    'Population Change': 60013.0,
#    'Personal Dist Income Per Capita Change': 1004.0},
#   'Mideast': {'GDP Change': 37556.19999999972,
#    'Personal Dist Income Change': 53366.89999999991,
#    'Population Change': 193583.0,
#    'Personal Dist Income Per Capita Change': 1003.0},
#   'GreatLakes': {'GDP Change': 41436.299999999814,
#    'Personal Dist Income Change': 43689.39999999991,
#    'Population Change': 157503.0,
#    'Personal Dist Income Per Capita Change': 860.0},
#   'Plains': {'GDP Change': 30329.800000000047,
#    'Personal Dist Income Change': 27927.0,
#    'Population Change': 101158.0,
#    'Personal Dist Income Per Capita Change': 1288.0},
#   'Southeast': {'GDP Change': 98638.70000000019,
#    'Personal Dist Income Change': 98678.3999999999,
#    'Population Change': 809925.0,
#    'Personal Dist Income Per Capita Change': 1082.0},
#   'Southwest': {'GDP Change': 26041.399999999907,
#    'Personal Dist Income Change': 42743.29999999993,
#    'Population Change': 492792.0,
#    'Personal Dist Income Per Capita Change': 916.0},
#   'RockyMountain': {'GDP Change': 6978.899999999965,
#    'Personal Dist Income Change': 10423.200000000012,
#    'Population Change': 108055.0,
#    'Personal Dist Income Per Capita Change': 779.0}},
#  2004: {'NewEngland': {'GDP Change': 31555.79999999993,
#    'Personal Dist Income Change': 27085.29999999999,
#    'Population Change': 24229.0,
#    'Personal Dist Income Per Capita Change': 1847.0},
#   'Mideast': {'GDP Change': 72756.80000000028,
#    'Personal Dist Income Change': 81363.3999999999,
#    'Population Change': 127569.0,
#    'Personal Dist Income Per Capita Change': 1637.0},
#   'GreatLakes': {'GDP Change': 46850.10000000009,
#    'Personal Dist Income Change': 54264.10000000009,
#    'Population Change': 136585.0,
#    'Personal Dist Income Per Capita Change': 1098.0},
#   'Plains': {'GDP Change': 30888.599999999977,
#    'Personal Dist Income Change': 31505.099999999977,
#    'Population Change': 118766.0,
#    'Personal Dist Income Per Capita Change': 1429.0},
#   'Southeast': {'GDP Change': 138304.7999999998,
#    'Personal Dist Income Change': 138091.0,
#    'Population Change': 1057638.0,
#    'Personal Dist Income Per Capita Change': 1503.0},
#   'Southwest': {'GDP Change': 74342.80000000005,
#    'Personal Dist Income Change': 53074.09999999998,
#    'Population Change': 551707.0,
#    'Personal Dist Income Per Capita Change': 1149.0},
#   'RockyMountain': {'GDP Change': 12413.0,
#    'Personal Dist Income Change': 14537.599999999977,
#    'Population Change': 132178.0,
#    'Personal Dist Income Per Capita Change': 1112.0}},
#  2005: {'NewEngland': {'GDP Change': 14684.300000000047,
#    'Personal Dist Income Change': 16149.5,
#    'Population Change': 9973.0,
#    'Personal Dist Income Per Capita Change': 1111.0},
#   'Mideast': {'GDP Change': 69946.6000000001,
#    'Personal Dist Income Change': 51092.0,
#    'Population Change': 76897.0,
#    'Personal Dist Income Per Capita Change': 1025.0},
#   'GreatLakes': {'GDP Change': 35569.80000000028,
#    'Personal Dist Income Change': 32392.5,
#    'Population Change': 104770.0,
#    'Personal Dist Income Per Capita Change': 637.0},
#   'Plains': {'GDP Change': 24631.099999999977,
#    'Personal Dist Income Change': 15514.900000000023,
#    'Population Change': 114797.0,
#    'Personal Dist Income Per Capita Change': 611.0},
#   'Southeast': {'GDP Change': 147513.6000000001,
#    'Personal Dist Income Change': 121870.1000000001,
#    'Population Change': 1129157.0,
#    'Personal Dist Income Per Capita Change': 1214.0},
#   'Southwest': {'GDP Change': 56589.0,
#    'Personal Dist Income Change': 72583.90000000002,
#    'Population Change': 622603.0,
#    'Personal Dist Income Per Capita Change': 1625.0},
#   'RockyMountain': {'GDP Change': 23899.900000000023,
#    'Personal Dist Income Change': 17522.29999999999,
#    'Population Change': 164597.0,
#    'Personal Dist Income Per Capita Change': 1285.0}},
#  2006: {'NewEngland': {'GDP Change': 19653.199999999953,
#    'Personal Dist Income Change': 38035.0,
#    'Population Change': 28884.0,
#    'Personal Dist Income Per Capita Change': 2593.0},
#   'Mideast': {'GDP Change': 50942.799999999814,
#    'Personal Dist Income Change': 98348.5,
#    'Population Change': 95196.0,
#    'Personal Dist Income Per Capita Change': 2007.0},
#   'GreatLakes': {'GDP Change': 18496.69999999972,
#    'Personal Dist Income Change': 67411.79999999981,
#    'Population Change': 122431.0,
#    'Personal Dist Income Per Capita Change': 1383.0},
#   'Plains': {'GDP Change': 14331.600000000093,
#    'Personal Dist Income Change': 34478.59999999998,
#    'Population Change': 154252.0,
#    'Personal Dist Income Per Capita Change': 1493.0},
#   'Southeast': {'GDP Change': 89354.79999999981,
#    'Personal Dist Income Change': 150872.5,
#    'Population Change': 917561.0,
#    'Personal Dist Income Per Capita Change': 1649.0},
#   'Southwest': {'GDP Change': 103341.19999999995,
#    'Personal Dist Income Change': 92921.20000000007,
#    'Population Change': 846877.0,
#    'Personal Dist Income Per Capita Change': 1950.0},
#   'RockyMountain': {'GDP Change': 22640.400000000023,
#    'Personal Dist Income Change': 25431.29999999999,
#    'Population Change': 217851.0,
#    'Personal Dist Income Per Capita Change': 1857.0}},
#  2007: {'NewEngland': {'GDP Change': 17495.900000000023,
#    'Personal Dist Income Change': 24442.0,
#    'Population Change': 33665.0,
#    'Personal Dist Income Per Capita Change': 1617.0},
#   'Mideast': {'GDP Change': 28361.899999999907,
#    'Personal Dist Income Change': 94501.5,
#    'Population Change': 139283.0,
#    'Personal Dist Income Per Capita Change': 1881.0},
#   'GreatLakes': {'GDP Change': 15805.5,
#    'Personal Dist Income Change': 56355.90000000014,
#    'Population Change': 116419.0,
#    'Personal Dist Income Per Capita Change': 1140.0},
#   'Plains': {'GDP Change': 20425.599999999977,
#    'Personal Dist Income Change': 38188.40000000002,
#    'Population Change': 148715.0,
#    'Personal Dist Income Per Capita Change': 1663.0},
#   'Southeast': {'GDP Change': 6204.5,
#    'Personal Dist Income Change': 119048.19999999972,
#    'Population Change': 1056902.0,
#    'Personal Dist Income Per Capita Change': 1132.0},
#   'Southwest': {'GDP Change': 75023.80000000005,
#    'Personal Dist Income Change': 61065.39999999991,
#    'Population Change': 679135.0,
#    'Personal Dist Income Per Capita Change': 1120.0},
#   'RockyMountain': {'GDP Change': 20039.900000000023,
#    'Personal Dist Income Change': 21175.0,
#    'Population Change': 216343.0,
#    'Personal Dist Income Per Capita Change': 1374.0}},
#  2008: {'NewEngland': {'GDP Change': 1511.8000000000466,
#    'Personal Dist Income Change': 30769.099999999977,
#    'Population Change': 60910.0,
#    'Personal Dist Income Per Capita Change': 1968.0},
#   'Mideast': {'GDP Change': -4344.299999999814,
#    'Personal Dist Income Change': 56217.90000000014,
#    'Population Change': 211168.0,
#    'Personal Dist Income Per Capita Change': 1004.0},
#   'GreatLakes': {'GDP Change': -46538.299999999814,
#    'Personal Dist Income Change': 48641.89999999991,
#    'Population Change': 87128.0,
#    'Personal Dist Income Per Capita Change': 989.0},
#   'Plains': {'GDP Change': 12998.29999999993,
#    'Personal Dist Income Change': 40704.90000000002,
#    'Population Change': 143118.0,
#    'Personal Dist Income Per Capita Change': 1773.0},
#   'Southeast': {'GDP Change': -25118.899999999907,
#    'Personal Dist Income Change': 86760.6000000001,
#    'Population Change': 934991.0,
#    'Personal Dist Income Per Capita Change': 735.0},
#   'Southwest': {'GDP Change': -365.39999999990687,
#    'Personal Dist Income Change': 90757.80000000005,
#    'Population Change': 644956.0,
#    'Personal Dist Income Per Capita Change': 1928.0},
#   'RockyMountain': {'GDP Change': 5266.0,
#    'Personal Dist Income Change': 16520.100000000035,
#    'Population Change': 203236.0,
#    'Personal Dist Income Per Capita Change': 923.0}},
#  2009: {'NewEngland': {'GDP Change': -18271.100000000093,
#    'Personal Dist Income Change': 14578.70000000007,
#    'Population Change': 63460.0,
#    'Personal Dist Income Per Capita Change': 819.0},
#   'Mideast': {'GDP Change': 7864.5,
#    'Personal Dist Income Change': 32532.899999999907,
#    'Population Change': 258986.0,
#    'Personal Dist Income Per Capita Change': 461.0},
#   'GreatLakes': {'GDP Change': -109444.6000000001,
#    'Personal Dist Income Change': -17323.09999999986,
#    'Population Change': 80734.0,
#    'Personal Dist Income Per Capita Change': -432.0},
#   'Plains': {'GDP Change': -23143.29999999993,
#    'Personal Dist Income Change': -2740.4000000000233,
#    'Population Change': 143768.0,
#    'Personal Dist Income Per Capita Change': -383.0},
#   'Southeast': {'GDP Change': -118869.79999999981,
#    'Personal Dist Income Change': -19907.19999999972,
#    'Population Change': 757096.0,
#    'Personal Dist Income Per Capita Change': -577.0},
#   'Southwest': {'GDP Change': -26995.100000000093,
#    'Personal Dist Income Change': -23276.399999999907,
#    'Population Change': 630250.0,
#    'Personal Dist Income Per Capita Change': -1216.0},
#   'RockyMountain': {'GDP Change': -12675.400000000023,
#    'Personal Dist Income Change': -6230.900000000023,
#    'Population Change': 184351.0,
#    'Personal Dist Income Per Capita Change': -1159.0}},
#  2010: {'NewEngland': {'GDP Change': 21053.300000000047,
#    'Personal Dist Income Change': 25267.79999999993,
#    'Population Change': 66208.0,
#    'Personal Dist Income Per Capita Change': 1542.0},
#   'Mideast': {'GDP Change': 84240.79999999981,
#    'Personal Dist Income Change': 71590.5,
#    'Population Change': 260312.0,
#    'Personal Dist Income Per Capita Change': 1265.0},
#   'GreatLakes': {'GDP Change': 70164.5,
#    'Personal Dist Income Change': 44333.299999999814,
#    'Population Change': 82685.0,
#    'Personal Dist Income Per Capita Change': 895.0},
#   'Plains': {'GDP Change': 26237.699999999953,
#    'Personal Dist Income Change': 24087.199999999953,
#    'Population Change': 143627.0,
#    'Personal Dist Income Per Capita Change': 929.0},
#   'Southeast': {'GDP Change': 64172.0,
#    'Personal Dist Income Change': 97504.59999999963,
#    'Population Change': 756497.0,
#    'Personal Dist Income Per Capita Change': 929.0},
#   'Southwest': {'GDP Change': 31895.199999999953,
#    'Personal Dist Income Change': 58632.0,
#    'Population Change': 575384.0,
#    'Personal Dist Income Per Capita Change': 1058.0},
#   'RockyMountain': {'GDP Change': 5448.400000000023,
#    'Personal Dist Income Change': 11821.700000000012,
#    'Population Change': 155705.0,
#    'Personal Dist Income Per Capita Change': 612.0}},
#  2011: {'NewEngland': {'GDP Change': 4860.900000000023,
#    'Personal Dist Income Change': 17574.5,
#    'Population Change': 59869.0,
#    'Personal Dist Income Per Capita Change': 1019.0},
#   'Mideast': {'GDP Change': 14199.399999999907,
#    'Personal Dist Income Change': 86385.59999999986,
#    'Population Change': 232605.0,
#    'Personal Dist Income Per Capita Change': 1581.0},
#   'GreatLakes': {'GDP Change': 47133.700000000186,
#    'Personal Dist Income Change': 74162.30000000005,
#    'Population Change': 74536.0,
#    'Personal Dist Income Per Capita Change': 1539.0},
#   'Plains': {'GDP Change': 19394.900000000023,
#    'Personal Dist Income Change': 45525.80000000005,
#    'Population Change': 103346.0,
#    'Personal Dist Income Per Capita Change': 2026.0},
#   'Southeast': {'GDP Change': 20615.799999999814,
#    'Personal Dist Income Change': 114767.70000000019,
#    'Population Change': 668009.0,
#    'Personal Dist Income Per Capita Change': 1167.0},
#   'Southwest': {'GDP Change': 53862.40000000014,
#    'Personal Dist Income Change': 89247.3999999999,
#    'Population Change': 513267.0,
#    'Personal Dist Income Per Capita Change': 1889.0},
#   'RockyMountain': {'GDP Change': 8031.399999999907,
#    'Personal Dist Income Change': 25480.79999999999,
#    'Population Change': 134667.0,
#    'Personal Dist Income Per Capita Change': 1892.0}},
#  2012: {'NewEngland': {'GDP Change': 12552.400000000023,
#    'Personal Dist Income Change': 26731.20000000007,
#    'Population Change': 60218.0,
#    'Personal Dist Income Per Capita Change': 1638.0},
#   'Mideast': {'GDP Change': 73101.6000000001,
#    'Personal Dist Income Change': 105713.0,
#    'Population Change': 187055.0,
#    'Personal Dist Income Per Capita Change': 2006.0},
#   'GreatLakes': {'GDP Change': 28198.0,
#    'Personal Dist Income Change': 73023.5,
#    'Population Change': 73838.0,
#    'Personal Dist Income Per Capita Change': 1511.0},
#   'Plains': {'GDP Change': 23642.899999999907,
#    'Personal Dist Income Change': 44490.19999999995,
#    'Population Change': 110468.0,
#    'Personal Dist Income Per Capita Change': 1942.0},
#   'Southeast': {'GDP Change': 27830.100000000093,
#    'Personal Dist Income Change': 122072.0,
#    'Population Change': 686428.0,
#    'Personal Dist Income Per Capita Change': 1231.0},
#   'Southwest': {'GDP Change': 81474.19999999995,
#    'Personal Dist Income Change': 91733.69999999995,
#    'Population Change': 564458.0,
#    'Personal Dist Income Per Capita Change': 1852.0},
#   'RockyMountain': {'GDP Change': 6028.70000000007,
#    'Personal Dist Income Change': 25562.900000000023,
#    'Population Change': 138393.0,
#    'Personal Dist Income Per Capita Change': 1842.0}},
#  2013: {'NewEngland': {'GDP Change': -1390.9000000000233,
#    'Personal Dist Income Change': -13809.800000000047,
#    'Population Change': 54927.0,
#    'Personal Dist Income Per Capita Change': -1126.0},
#   'Mideast': {'GDP Change': 7644.700000000186,
#    'Personal Dist Income Change': -12161.799999999814,
#    'Population Change': 136955.0,
#    'Personal Dist Income Per Capita Change': -377.0},
#   'GreatLakes': {'GDP Change': 27559.0,
#    'Personal Dist Income Change': 11410.600000000093,
#    'Population Change': 106600.0,
#    'Personal Dist Income Per Capita Change': 159.0},
#   'Plains': {'GDP Change': 13000.600000000093,
#    'Personal Dist Income Change': 745.8000000000466,
#    'Population Change': 120598.0,
#    'Personal Dist Income Per Capita Change': -194.0},
#   'Southeast': {'GDP Change': 37269.69999999972,
#    'Personal Dist Income Change': -16192.299999999814,
#    'Population Change': 626932.0,
#    'Personal Dist Income Per Capita Change': -479.0},
#   'Southwest': {'GDP Change': 65611.3999999999,
#    'Personal Dist Income Change': 22615.699999999953,
#    'Population Change': 518062.0,
#    'Personal Dist Income Per Capita Change': 78.0},
#   'RockyMountain': {'GDP Change': 14767.699999999953,
#    'Personal Dist Income Change': 12988.599999999977,
#    'Population Change': 152973.0,
#    'Personal Dist Income Per Capita Change': 641.0}},
#  2014: {'NewEngland': {'GDP Change': 6776.79999999993,
#    'Personal Dist Income Change': 31323.300000000047,
#    'Population Change': 58856.0,
#    'Personal Dist Income Per Capita Change': 1939.0},
#   'Mideast': {'GDP Change': 54745.5,
#    'Personal Dist Income Change': 90186.3999999999,
#    'Population Change': 104686.0,
#    'Personal Dist Income Per Capita Change': 1748.0},
#   'GreatLakes': {'GDP Change': 49493.299999999814,
#    'Personal Dist Income Change': 80949.3999999999,
#    'Population Change': 74518.0,
#    'Personal Dist Income Per Capita Change': 1671.0},
#   'Plains': {'GDP Change': 25528.899999999907,
#    'Personal Dist Income Change': 35037.79999999993,
#    'Population Change': 113585.0,
#    'Personal Dist Income Per Capita Change': 1455.0},
#   'Southeast': {'GDP Change': 54056.40000000037,
#    'Personal Dist Income Change': 164135.3999999999,
#    'Population Change': 696152.0,
#    'Personal Dist Income Per Capita Change': 1718.0},
#   'Southwest': {'GDP Change': 56644.40000000014,
#    'Personal Dist Income Change': 105609.80000000005,
#    'Population Change': 609231.0,
#    'Personal Dist Income Per Capita Change': 2079.0},
#   'RockyMountain': {'GDP Change': 18736.20000000007,
#    'Personal Dist Income Change': 31475.900000000023,
#    'Population Change': 148909.0,
#    'Personal Dist Income Per Capita Change': 2242.0}},
#  2015: {'NewEngland': {'GDP Change': 23882.70000000007,
#    'Personal Dist Income Change': 32766.099999999977,
#    'Population Change': 25895.0,
#    'Personal Dist Income Per Capita Change': 2137.0},
#   'Mideast': {'GDP Change': 52944.0,
#    'Personal Dist Income Change': 87191.70000000019,
#    'Population Change': 55938.0,
#    'Personal Dist Income Per Capita Change': 1729.0},
#   'GreatLakes': {'GDP Change': 24070.700000000186,
#    'Personal Dist Income Change': 72168.80000000005,
#    'Population Change': 16436.0,
#    'Personal Dist Income Per Capita Change': 1529.0},
#   'Plains': {'GDP Change': 13509.700000000186,
#    'Personal Dist Income Change': 25343.100000000093,
#    'Population Change': 100465.0,
#    'Personal Dist Income Per Capita Change': 1006.0},
#   'Southeast': {'GDP Change': 89652.69999999972,
#    'Personal Dist Income Change': 142905.2999999998,
#    'Population Change': 788559.0,
#    'Personal Dist Income Per Capita Change': 1386.0},
#   'Southwest': {'GDP Change': 92343.0,
#    'Personal Dist Income Change': 37183.5,
#    'Population Change': 640761.0,
#    'Personal Dist Income Per Capita Change': 287.0},
#   'RockyMountain': {'GDP Change': 22578.79999999993,
#    'Personal Dist Income Change': 23340.79999999999,
#    'Population Change': 177763.0,
#    'Personal Dist Income Per Capita Change': 1385.0}},
#  2016: {'NewEngland': {'GDP Change': 10243.0,
#    'Personal Dist Income Change': 22085.900000000023,
#    'Population Change': 29598.0,
#    'Personal Dist Income Per Capita Change': 1393.0},
#   'Mideast': {'GDP Change': 41720.60000000009,
#    'Personal Dist Income Change': 79637.5,
#    'Population Change': 18703.0,
#    'Personal Dist Income Per Capita Change': 1608.0},
#   'GreatLakes': {'GDP Change': 22860.899999999907,
#    'Personal Dist Income Change': 42788.39999999991,
#    'Population Change': 35623.0,
#    'Personal Dist Income Per Capita Change': 882.0},
#   'Plains': {'GDP Change': 4643.59999999986,
#    'Personal Dist Income Change': 11287.699999999953,
#    'Population Change': 92155.0,
#    'Personal Dist Income Per Capita Change': 350.0},
#   'Southeast': {'GDP Change': 59805.89999999991,
#    'Personal Dist Income Change': 95673.80000000028,
#    'Population Change': 858929.0,
#    'Personal Dist Income Per Capita Change': 757.0},
#   'Southwest': {'GDP Change': 8547.299999999814,
#    'Personal Dist Income Change': 18607.699999999953,
#    'Population Change': 582050.0,
#    'Personal Dist Income Per Capita Change': -118.0},
#   'RockyMountain': {'GDP Change': 13054.0,
#    'Personal Dist Income Change': 11563.200000000012,
#    'Population Change': 189319.0,
#    'Personal Dist Income Per Capita Change': 311.0}},
#  2017: {'NewEngland': {'GDP Change': 13363.0,
#    'Personal Dist Income Change': 32540.699999999953,
#    'Population Change': 43821.0,
#    'Personal Dist Income Per Capita Change': 2041.0},
#   'Mideast': {'GDP Change': 60574.09999999963,
#    'Personal Dist Income Change': 127209.0,
#    'Population Change': 7243.0,
#    'Personal Dist Income Per Capita Change': 2592.0},
#   'GreatLakes': {'GDP Change': 31992.19999999972,
#    'Personal Dist Income Change': 68800.0,
#    'Population Change': 58815.0,
#    'Personal Dist Income Per Capita Change': 1416.0},
#   'Plains': {'GDP Change': 9041.600000000093,
#    'Personal Dist Income Change': 26874.5,
#    'Population Change': 100303.0,
#    'Personal Dist Income Per Capita Change': 1063.0},
#   'Southeast': {'GDP Change': 74852.1000000001,
#    'Personal Dist Income Change': 142104.0,
#    'Population Change': 768965.0,
#    'Personal Dist Income Per Capita Change': 1339.0},
#   'Southwest': {'GDP Change': 31957.5,
#    'Personal Dist Income Change': 72983.6000000001,
#    'Population Change': 495126.0,
#    'Personal Dist Income Per Capita Change': 1283.0},
#   'RockyMountain': {'GDP Change': 14258.599999999977,
#    'Personal Dist Income Change': 26136.20000000001,
#    'Population Change': 178331.0,
#    'Personal Dist Income Per Capita Change': 1548.0}}}
